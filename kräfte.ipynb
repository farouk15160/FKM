# %%
from IPython.display import display, Markdown
import math

space="""
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
$$
        
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
$$
        
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$


"""

# %%
Nx= 10 # KN
L_Welle=600 #mm
d = 260 # mm 
display(Markdown(f"""
# Mechanisches Ersatzbild und Belastungsverläufe der Welle      

#### Die Länge der Welle berägt : {L_Welle} mm 
#### Der Durchmesser der Welle berägt : {d} mm 
#### Die Welle hat Zwei Wälzlager , ein Fester ein Loser 

{space}
{space}
{space}




"""))
# Out:
# # Mechanisches Ersatzbild und Belastungsverläufe der Welle
#
# #### Die Länge der Welle berägt : 600 mm
# #### Der Durchmesser der Welle berägt : 260 mm
# #### Die Welle hat Zwei Wälzlager , ein Loser ein Fester
#
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
#
#
#
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# ...
