# %%
from IPython.display import display, Markdown
import math

space="""
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
$$
        
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
$$
        
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$


"""

# %%
Nx= 10 # KN
L_Welle=1400 #mm
d = 550 # mm 
display(Markdown(f"""
# Mechanisches Ersatzbild und Belastungsverläufe der Welle      

#### Die Länge der Welle berägt : {L_Welle} mm 
#### Der Durchmesser der Welle berägt : {d} mm 
#### Die Welle hat Zwei Wälzlager , ein Fester ein Loser 

{space}
{space}
{space}




"""))
# Out:
# # Mechanisches Ersatzbild und Belastungsverläufe der Welle
#
# #### Die Länge der Welle berägt : 1400 mm
# #### Der Durchmesser der Welle berägt : 550 mm
# #### Die Welle hat Zwei Wälzlager , ein Fester ein Loser
#
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
#
#
#
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
#
#
#
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$

# %%
Nx=10
Ax=Nx
Bx=615.385
Ay=8615.385
Fg=8000 
M_t=(Fg/1000)*d/2
display(Markdown(f"""
# Kräfteverlaüfe
### Es gibt Kräfte in X-Y-Richtung , daraus folgt folgneds Werte:
$$
\Large
N_{{x}}={Nx} \\ KN \\\\\\ \\\\\\ \\\\\\
A_{{x}}={Ax} \\ KN \\\\\\ \\\\\\ \\\\\\
A_{{y}}={Ay} \\ KN \\\\\\ \\\\\\ \\\\\\
B_{{x}}={Bx} \\ KN \\\\\\ \\\\\\ \\\\\\
F_{{g}}={Fg} \\ KN \\\\\\ \\\\\\ \\\\\\
$$


## Gößeschnitte:
$$
\Large
N_{{x}} = {Nx} \\ KN \\\\\\ \\\\\\ \\\\\\
M_{{b_{{y}}}} = {-800}\\ KN-m \\\\\\ \\\\\\ \\\\\\
Q_{{y_{{min}}}} = {-8000}\\ KN \\\\\\ \\\\\\ \\\\\\
Q_{{y_{{max}}}} = {615.385}\\ KN \\\\\\ \\\\\\ \\\\\\
M_{{t}} = {M_t} KN-m \\\\\\ \\\\\\ \\\\\\
N_{{y}} = {0}\\ KN \\ \\ \\
N_{{z}} = {0}\\ KN \\ \\ \\
Q_{{x}} = {0}\\ KN \\ \\ \\
Q_{{z}} = {0}\\ KN \\ \\ \\
M_{{b_{{x}}}} = {0}\\ KN-m \\ \\ \\
M_{{b_{{z}}}} = {0}\\ KN-m \\ \\ \\
$$

## Kräfteverlüfe
                 
                 """))
# Out:
# # Kräfteverlaüfe
# ### Es gibt Kräfte in X-Y-Richtung , daraus folgt folgneds Werte:
# $$
# \Large
# N_{x}=10 \ KN \\\ \\\ \\\
# A_{x}=10 \ KN \\\ \\\ \\\
# A_{y}=8615.385 \ KN \\\ \\\ \\\
# B_{x}=615.385 \ KN \\\ \\\ \\\
# F_{g}=8000 \ KN \\\ \\\ \\\
# $$
#
#
# ## Gößeschnitte:
# $$
# \Large
# N_{x} = 10 \ KN \\\ \\\ \\\
# M_{b_{y}} = -800\ KN-m \\\ \\\ \\\
# Q_{y_{min}} = -8000\ KN \\\ \\\ \\\
# Q_{y_{max}} = 615.385\ KN \\\ \\\ \\\
# M_{t} = 2200.0 KN-m \\\ \\\ \\\
# N_{y} = 0\ KN \ \ \
# N_{z} = 0\ KN \ \ \
# Q_{x} = 0\ KN \ \ \
# Q_{z} = 0\ KN \ \ \
# M_{b_{x}} = 0\ KN-m \ \ \
# M_{b_{z}} = 0\ KN-m \ \ \
# $$
#
# ## Kräfteverlüfe
