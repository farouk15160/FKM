# %%
from IPython.display import display, Markdown
import math

space="""
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
$$
        
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
$$
        
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$


"""

# %%
display(Markdown(f"""
# Handskizze der Anlage:
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$

![Handskizze der Anlage](hand_skizze.jpg)
{space}
"""))
# Out:
# # Handskizze der Anlage:
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
#
# ![Handskizze der Anlage](hand_skizze.jpg)
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$

# %%
Nx= 10 # KN
L_Welle=600 #mm
d = 150 # mm 
display(Markdown(f"""
# Mechanisches Ersatzbild und Belastungsverläufe der Welle \\\\                 
#### Die Länge der Welle berägt : {L_Welle} mm 
#### Der Durchmesser der Welle berägt : {d} mm 
#### Die Welle hat Zwei Wälzlager , ein Loser ein Fester 

{space}
{space}
{space}

### In X-Richtung
##### Die Welle wird in x-Richtung durch die Axial-Kraft constant belastet
##### $$ N_{{x}} = {Nx} \\  KN   \\  Führt \\  dazu \\ , B_{{x}}= {Nx} \\ KN $$ 
        
        
{space}
{space}
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
$$
        
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
$$
        



"""))
# Out:
# # Mechanisches Ersatzbild und Belastungsverläufe der Welle \\
# #### Die Länge der Welle berägt : 600 mm
# #### Der Durchmesser der Welle berägt : 150 mm
# #### Die Welle hat Zwei Wälzlager , ein Loser ein Fester
#
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
#
#
#
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# ...

# %%
Fy= 8000 # KN
L_Welle=600 #mm
d = 150 # mm 
display(Markdown(f"""
### In Y-Richtung
##### Die Welle wird in y-Richtung durch die Das Gewicht der Rotor/Nabe 
$$ \large F_{{y}} = {Fy} \\  KN $$     
$$ \large Q_{{yI}} = 8000 \\  KN  $$
$$ \large Q_{{yII}} = -1600 \\  KN  $$
$$ \large A_{{y}} = -9600 \\  KN  $$
$$ \large B_{{y}} = 1600 \\  KN  $$
{space}
{space}



"""))
# Out:
# ### In Y-Richtung
# ##### Die Welle wird in y-Richtung durch die Das Gewicht der Rotor/Nabe
# $$ \large F_{y} = 8000 \  KN $$
# $$ \large Q_{yI} = 8000 \  KN  $$
# $$ \large Q_{yII} = -1600 \  KN  $$
# $$ \large A_{y} = -9600 \  KN  $$
# $$ \large B_{y} = 1600 \  KN  $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
#
#
#
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# ...

# %%
Fz= 8000 # KN
 
display(Markdown(f"""
### In Z-Richtung
##### Die Welle wird in z-Richtung durch die Das Gewicht der Rotor/Nabe 

$$ \large F_{{z}} = {Fz} \\  KN $$     
$$ \large Q_{{zI}} = 8000 \\  KN  $$
$$  \large Q_{{zII}} = -1600 \\  KN  $$
$$ \large A_{{z}} = -9600 \\  KN  $$
$$ \large B_{{z}} = 1600 \\  KN  $$
{space}
{space}
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
\\\\\\
$$
$$
\\\\\\
\\\\\\
\\\\\\
$$
        

$$
\\\\\\
\\\\\\
\\\\\\
$$
   


"""))
# Out:
# ### In Z-Richtung
# ##### Die Welle wird in z-Richtung durch die Das Gewicht der Rotor/Nabe
#
# $$ \large F_{z} = 8000 \  KN $$
# $$ \large Q_{zI} = 8000 \  KN  $$
# $$  \large Q_{zII} = -1600 \  KN  $$
# $$ \large A_{z} = -9600 \  KN  $$
# $$ \large B_{z} = 1600 \  KN  $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
#
#
#
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# $$
#
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# \\\
# $$
# $$
# ...

# %%
display(Markdown(f"""
### Torsion $$ M_{{T}} $$ 

$$
M_{{T}}= F \cdot r = 8000 \\ KN \cdot {d/2} \\ mm = {8000 * d/2000} \\ KNm 
$$
                 """))
# Out:
# ### Torsion $$ M_{T} $$
#
# $$
# M_{T}= F \cdot r = 8000 \ KN \cdot 75.0 \ mm = 600.0 \ KNm
# $$
